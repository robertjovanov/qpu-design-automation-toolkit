# %% [markdown]
# # Plunger Gate Sweep

# %% [markdown]
# This notebook showcases the effect of the plunger gate on various physical quantities throughout the device as we sweep its voltage bias.

# %% [markdown]
# ### 0. Setup

# %% [markdown]
# #### - Imports

# %%
import sys
import importlib
from pathlib import Path
import numpy as np

REPO_ROOT = Path("/Users/robertjovanov/code/qpu-design-automation-toolkit")
SRC = REPO_ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import nextnano_analysis as nna

# %% [markdown]
# #### - Helper functions

# %%
from pathlib import Path
import re
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def make_xqd_potential_gif(
    sweep_root: str | Path,
    out_gif: str | Path,
    bias_folder: str = "bias_00000",
    rel_file: str = "potential_1d_x_QD.dat",
    duration_s: float = 0.35,
    xlim: tuple[float, float] | None = None,
    ylim: tuple[float, float] | None = None,
    subtract_reference: str | None = None,  # None | "x0" | "xmin"
):
    """
    Create a GIF of potential_1d_x_QD.dat over a V_PG sweep.

    subtract_reference:
      - None  : plot raw potential
      - "x0"  : plot phi(x) - phi(x=0) for each frame (highlights shape changes)
      - "xmin": plot phi(x) - phi(x at min x)
    """
    try:
        import imageio.v2 as imageio
    except Exception as e:
        raise ImportError("Missing dependency 'imageio'. Install with: pip install imageio") from e

    sweep_root = Path(sweep_root)
    out_gif = Path(out_gif)
    out_gif.parent.mkdir(parents=True, exist_ok=True)

    # Find subruns that contain the target file
    subruns = sorted([p for p in sweep_root.iterdir()
                      if p.is_dir() and (p / bias_folder / rel_file).exists()])
    if not subruns:
        raise FileNotFoundError(f"No subruns with {bias_folder}/{rel_file} found under {sweep_root}")

    # Parse V_PG from folder name like: ...__V_PG_-0.2_...
    def parse_vpg(folder_name: str) -> float:
        m = re.search(r"__V_PG_(-?\d+(?:\.\d+)?)_", folder_name)
        if m:
            return float(m.group(1))
        # fallback: any float in name
        m2 = re.search(r"(-?\d+(?:\.\d+)?)", folder_name)
        if m2:
            return float(m2.group(1))
        raise ValueError(f"Could not parse V_PG from folder name: {folder_name}")

    runs = [(parse_vpg(r.name), r) for r in subruns]
    runs.sort(key=lambda t: t[0], reverse=True)  # 0, -0.2, ... descending

    # Preload curves and compute global y-limits (unless user provides)
    series = []
    ymins, ymaxs = [], []

    for vpg, r in runs:
        df = pd.read_csv(r / bias_folder / rel_file, delim_whitespace=True, comment="#")
        xcol, ycol = df.columns[0], df.columns[-1]
        x = df[xcol].to_numpy()
        y = df[ycol].to_numpy()

        if subtract_reference == "x0":
            i0 = int(np.argmin(np.abs(x - 0.0)))
            y = y - y[i0]
        elif subtract_reference == "xmin":
            y = y - y[0]

        series.append((vpg, x, y, xcol))
        ymins.append(np.nanmin(y))
        ymaxs.append(np.nanmax(y))

    if ylim is None:
        pad = 0.05 * (max(ymaxs) - min(ymins) + 1e-12)
        ylim = (min(ymins) - pad, max(ymaxs) + pad)

    # Render frames
    frames = []
    for vpg, x, y, xcol in series:
        fig, ax = plt.subplots(figsize=(6.2, 4.0), dpi=160)
        ax.plot(x, y, linewidth=2)

        ax.set_title(f"x_QD potential   V_PG = {vpg:g} V")
        ax.set_xlabel(xcol)
        ax.set_ylabel("Potential (V)" if subtract_reference is None else "ΔPotential (V)")

        if xlim is not None:
            ax.set_xlim(*xlim)
        ax.set_ylim(*ylim)

        ax.grid(True, alpha=0.25)
        fig.tight_layout()

        buf = io.BytesIO()
        fig.savefig(buf, format="png")
        plt.close(fig)
        buf.seek(0)
        frames.append(imageio.imread(buf))

    imageio.mimsave(out_gif, frames, duration=duration_s, loop=0)
    return out_gif

# %% [markdown]
# ### 1. Empty QD

# %% [markdown]
# #### 1.1 Running the simulation sweep

# %%
INPUT_2D_EMPTY = Path("/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D.in")

VPG_base = np.round(np.arange(0.0, -3.0 - 1e-12, -0.2), 10).tolist()
VPG_extra = [-6.0, -10.0, -25.0, -50.0]
VPG = list(dict.fromkeys(VPG_base + VPG_extra))

sweep_variables = {"V_PG": VPG}

sw = nna.sweep_with_nn_sweep(
    INPUT_2D_EMPTY,
    sweep_variables=sweep_variables,
    delete_old_files=True,
    delete_input_files=False,
    overwrite=True,
    show_log=True,
    convergenceCheck=True,
    parallel_limit=1,
)

print("Sweep done. Points:", len(VPG))
print(sw)
# Out:
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_0.0_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_0.0_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_0.0_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Fri 2026-03-06, 17:58:16 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_0.0_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_0.0_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.0107741356[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  0.000000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.262575865[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7983716225
#   Newton step: 2	181657.7291403079
#   Newton step: 3	37531.31248562893
#   Newton step: 4	7223.155907444104
#   Newton step: 5	1390.785939317772
#   Newton step: 6	268.5179399519923
#   Newton step: 7	53.15774622006914
#   Newton step: 8	12.37229666585803
#   Newton step: 9	5.270808137014923
#   Newton step: 10	2.872587167524667
#   Newton step: 11	1.903183905167271
#   Newton step: 12	1.539871881212097
#   Newton step: 13	0.8959500355264015
#   Newton step: 14	0.6224312459945047
#   Newton step: 15	0.3644790925387412
#   Newton step: 16	0.2510600816096571
#   Newton step: 17	0.1502678867407747
#   Newton achieved/desired residual: 2.36687484e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.0116544439
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 -0.011654444
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         213        4260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.187774986
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         526       10520
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	2.36687483990623e-09
#   Newton achieved/desired residual: 9.36084962e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.011654444
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 8.618404052e-310
# QUANTUM-POISSON:   Residual_potential = 1.434951713e-09
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	9.360849620249525e-10
#   Newton achieved/desired residual: 9.36084962e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.011654444
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.388718039 -0.011654444
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.603763044 0.187774986
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 1.821187788e-308
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Fri 2026-03-06, 17:58:25 (+0100)
# Total Poisson Solver Time: 4.37334991[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.38214207[s]
# Total calculation time for matrix elements and lifetimes: 9.53674316e-07[s]
# Total Strain Solution Time: 0.0102519989[s]
# Total Time: 8.62632704[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.2_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.2_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.2_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Fri 2026-03-06, 17:58:25 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.2_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.2_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.00961899757[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.200000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.261888027[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7983709761
#   Newton step: 2	181657.7291397642
#   Newton step: 3	37531.31248516613
#   Newton step: 4	7223.155907061326
#   Newton step: 5	1390.785939311052
#   Newton step: 6	268.5179404723915
#   Newton step: 7	53.15774364470499
#   Newton step: 8	12.37227485896195
#   Newton step: 9	5.270691384021545
#   Newton step: 10	2.871999721570746
#   Newton step: 11	1.90294748089526
#   Newton step: 12	1.539399376860445
#   Newton step: 13	0.8958914955444136
#   Newton step: 14	0.6224003489827586
#   Newton step: 15	0.3644599631751843
#   Newton step: 16	0.2510455285809062
#   Newton step: 17	0.1502604482084615
#   Newton achieved/desired residual: 2.36503006e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.00398825426
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 0.00398825435
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         209        4180
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.204350501
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         528       10560
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	2.365030056518655e-09
#   Newton achieved/desired residual: 9.39803465e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.00398825424
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 2.630441170e-309
# QUANTUM-POISSON:   Residual_potential = 1.435244812e-09
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	9.39803464618532e-10
#   Newton achieved/desired residual: 9.39803465e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.00398825424
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.375092596 0.00398825435
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.591162324 0.204350501
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 3.277403167e-308
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Fri 2026-03-06, 17:58:33 (+0100)
# Total Poisson Solver Time: 4.34115219[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.323107[s]
# Total Strain Solution Time: 0.0144309998[s]
# Total Time: 8.46096706[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.4_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.4_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.4_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Fri 2026-03-06, 17:58:34 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.4_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.4_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.0101530552[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.400000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.261149883[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.798370329
#   Newton step: 2	181657.7291392227
#   Newton step: 3	37531.31248470346
#   Newton step: 4	7223.155906679097
#   Newton step: 5	1390.785939306744
#   Newton step: 6	268.5179410303477
#   Newton step: 7	53.15774242995909
#   Newton step: 8	12.37225720799209
#   Newton step: 9	5.270575615774381
#   Newton step: 10	2.871456640349247
#   Newton step: 11	1.902709979959496
#   Newton step: 12	1.538944014861538
#   Newton step: 13	0.895832984155027
#   Newton step: 14	0.6223694369758586
#   Newton step: 15	0.3644408320856531
#   Newton step: 16	0.2510309802095037
#   Newton step: 17	0.1502530064244424
#   Newton achieved/desired residual: 2.3669843e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0196309525
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 0.0196309518
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         208        4160
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.220926031
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         523       10460
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	2.366984295314099e-09
#   Newton achieved/desired residual: 9.36660449e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0196309524
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 2.446505965e-309
# QUANTUM-POISSON:   Residual_potential = 1.435070285e-09
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	9.36660449194704e-10
#   Newton achieved/desired residual: 9.36660449e-10 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0196309524
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.363605797 0.0196309518
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.580680311 0.220926031
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 3.041536756e-300
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Fri 2026-03-06, 17:58:42 (+0100)
# Total Poisson Solver Time: 4.37155604[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.31769109[s]
# Total Strain Solution Time: 0.0129861832[s]
# Total Time: 8.49847102[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.6_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.6_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.6_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Fri 2026-03-06, 17:58:43 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-0.6_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-0.6_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.0102519989[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.600000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.272964001[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# ...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 1.97420844
#   conduction band minimum: 0.412343909
# WARNING: Quantum region has no energy gap !!
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 1.40431726 1.99660254
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         126        2520
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 0.9070068 2.25971603
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 2.805261291e-08
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Fri 2026-03-06, 18:01:06 (+0100)
# Total Poisson Solver Time: 4.33239388[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.916905165[s]
# Total Strain Solution Time: 0.0100579262[s]
# Total Time: 7.98440599[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-50.0_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-50.0_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-50.0_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Fri 2026-03-06, 18:01:06 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D__V_PG_-50.0_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG/Single_Empty_Quantum_Dot_2D__V_PG_-50.0_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.00930285454[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -50.000000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.256615162[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7982217948
#   Newton step: 2	181657.72900594
#   Newton step: 3	37531.31237318124
#   Newton step: 4	7223.155824176976
#   Newton step: 5	1390.785997868416
#   Newton step: 6	268.5185173669539
#   Newton step: 7	53.15954455109108
#   Newton step: 8	12.3750142408127
#   Newton step: 9	5.265431806819802
#   Newton step: 10	2.822863880368285
#   Newton step: 11	1.862184672056238
#   Newton step: 12	1.422448635044018
#   Newton step: 13	0.8891224592860613
#   Newton step: 14	0.616501968556556
#   Newton step: 15	0.3600361056216212
#   Newton step: 16	0.2475404137718541
#   Newton step: 17	0.1484224389211201
#   Newton step: 18	0.0001374043912516221
#   Newton achieved/desired residual: 2.56213286e-07 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 4.07151841
#   conduction band minimum: 0.412343909
# WARNING: Quantum region has no energy gap !!
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 4.06778765
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 4.33090115
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         326        6520
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	0.0002830559138439138
#   Newton achieved/desired residual: 4.09681038e-07 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 4.07141308
#   conduction band minimum: 0.412343909
# WARNING: Quantum region has no energy gap !!
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 2.342833056e+02
# QUANTUM-POISSON:   Residual_potential = 1.276001830e-04
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	4.169713983323205e-07
#   Newton achieved/desired residual: 1.51514186e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 4.07141308
#   conduction band minimum: 0.412343909
# WARNING: Quantum region has no energy gap !!
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 3.29496479 4.06768084
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         126        2520
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 2.53017235 4.33079433
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 3.757798042e-01
# QUANTUM-POISSON:   Residual_potential = 2.205960214e-08
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Fri 2026-03-06, 18:01:14 (+0100)
# Total Poisson Solver Time: 4.57968402[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.892391682[s]
# Total Strain Solution Time: 0.0110669136[s]
# Total Time: 8.26804304[s]
#
# ================================================================================
# DONE.
# ================================================================================
# Sweep done. Points: 20
# Sweep
# fullpath: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D.in
# Input variables: 0 elements

# %% [markdown]
# #### 1.2 Lateral Dot Potential vs V_PG

# %%
from pathlib import Path
from IPython.display import Image, display

SWEEP_ROOT = Path("/Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Empty_Quantum_Dot_2D_sweep__V_PG")

gif_path = make_xqd_potential_gif(
    sweep_root=SWEEP_ROOT,
    out_gif=SWEEP_ROOT / "xQD_potential_vs_VPG.gif",
    duration_s=500,
    xlim=(-200, 200),
    subtract_reference=None  # use None if you want absolute potential instead
)

display(Image(filename=str(gif_path)))

# %% [markdown]
# ### 2. QD with Accummulation

# %% [markdown]
# #### 2.1 Running the simulation sweep

# %%
INPUT_2D_2DHG = Path("/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D.in")

VPG_base = np.round(np.arange(0.0, -3.0 - 1e-12, -0.2), 10).tolist()
VPG_extra = [-6.0, -10.0, -25.0, -50.0]
VPG = list(dict.fromkeys(VPG_base + VPG_extra))

sweep_variables = {"V_PG": VPG}

sw_2 = nna.sweep_with_nn_sweep(
    INPUT_2D_2DHG,
    sweep_variables=sweep_variables,
    delete_old_files=True,
    delete_input_files=False,
    overwrite=True,
    show_log=True,
    convergenceCheck=True,
    parallel_limit=1,
)

print("Sweep done. Points:", len(VPG))
print(sw_2)
# Out:
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_0.0_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_0.0_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_0.0_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Sat 2026-03-07, 10:32:43 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_0.0_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_0.0_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.00995898247[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  0.000000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.266016006[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7967626497
#   Newton step: 2	181657.7272422469
#   Newton step: 3	37531.3109651788
#   Newton step: 4	7223.154722575367
#   Newton step: 5	1390.784581188794
#   Newton step: 6	268.5139665091825
#   Newton step: 7	53.14284671111292
#   Newton step: 8	12.32888075570744
#   Newton step: 9	5.208507174664094
#   Newton step: 10	2.773991057866349
#   Newton step: 11	1.83463906510893
#   Newton step: 12	1.379444210036399
#   Newton step: 13	0.8752556653545837
#   Newton step: 14	0.6102811582089211
#   Newton step: 15	0.3571789867254686
#   Newton step: 16	0.2455923348280308
#   Newton step: 17	0.1473614215126679
#   Newton step: 18	3.700689104715221e-05
#   Newton achieved/desired residual: 1.63281378e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.157155132
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 -0.157155126
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         216        4320
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.0354306139
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         539       10780
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.632813778665322e-09
#   Newton achieved/desired residual: 1.63281378e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.157155132
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 1.542967012e-312
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.632813778665322e-09
#   Newton achieved/desired residual: 1.63281378e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.157155132
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.514589608 -0.157155126
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.707939923 0.0354306139
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 6.572500939e-311
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Sat 2026-03-07, 10:32:52 (+0100)
# Total Poisson Solver Time: 4.52171111[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.45499611[s]
# Total calculation time for matrix elements and lifetimes: 9.53674316e-07[s]
# Total Strain Solution Time: 0.0171229839[s]
# Total Time: 8.8189888[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.2_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.2_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.2_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Sat 2026-03-07, 10:32:52 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.2_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.2_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.00999498367[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.200000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.292958021[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7967292327
#   Newton step: 2	181657.7272135701
#   Newton step: 3	37531.31094094369
#   Newton step: 4	7223.154701641399
#   Newton step: 5	1390.7845606865
#   Newton step: 6	268.5139411633103
#   Newton step: 7	53.14276982419873
#   Newton step: 8	12.32859665215789
#   Newton step: 9	5.208068199883829
#   Newton step: 10	2.773162724411221
#   Newton step: 11	1.830689772174619
#   Newton step: 12	1.375281033458533
#   Newton step: 13	0.8744461314438032
#   Newton step: 14	0.6096386752928211
#   Newton step: 15	0.3567516733613625
#   Newton step: 16	0.2452771969121242
#   Newton step: 17	0.1471870874062654
#   Newton step: 18	6.243438968288548e-05
#   Newton achieved/desired residual: 3.6487729e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.146872007
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 -0.146872014
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         216        4320
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.0463614389
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         539       10780
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	3.648772903082686e-09
#   Newton achieved/desired residual: 1.50127497e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.146872007
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 5.373402005e-03
# QUANTUM-POISSON:   Residual_potential = 1.578077669e-10
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.501274971459467e-09
#   Newton achieved/desired residual: 1.50127497e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.146872007
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.505835772 -0.146872014
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.701589167 0.0463614389
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         326        6520
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 6.995822758e-309
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Sat 2026-03-07, 10:33:01 (+0100)
# Total Poisson Solver Time: 4.52138209[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.5199101[s]
# Total Strain Solution Time: 0.0190989971[s]
# Total Time: 9.11470079[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.4_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.4_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.4_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Sat 2026-03-07, 10:33:01 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.4_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.4_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.0107288361[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.400000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.297204018[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.7966961927
#   Newton step: 2	181657.7271849362
#   Newton step: 3	37531.31091681026
#   Newton step: 4	7223.154681065746
#   Newton step: 5	1390.784541567426
#   Newton step: 6	268.5139231642508
#   Newton step: 7	53.14274162088239
#   Newton step: 8	12.32851871457254
#   Newton step: 9	5.207952058273968
#   Newton step: 10	2.772984749489768
#   Newton step: 11	1.826588024798888
#   Newton step: 12	1.373523376977333
#   Newton step: 13	0.9356628258227899
#   Newton step: 14	0.6100434431292067
#   Newton step: 15	0.3564898032736468
#   Newton step: 16	0.2449831804037155
#   Newton step: 17	0.1470297259663233
#   Newton step: 18	6.006646882546343e-05
#   Newton achieved/desired residual: 4.93124479e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.137527096
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 -0.137527093
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         214        4280
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.0562987216
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         537       10740
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	4.931244790440169e-09
#   Newton achieved/desired residual: 1.30574287e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.137527096
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 9.125652188e-03
# QUANTUM-POISSON:   Residual_potential = 2.764308782e-10
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.305742873835104e-09
#   Newton achieved/desired residual: 1.30574287e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.137527096
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.499815583 -0.137527093
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.69598788 0.0562987216
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         326        6520
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 3.040549850e-300
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Sat 2026-03-07, 10:33:11 (+0100)
# Total Poisson Solver Time: 4.93163085[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.80718422[s]
# Total Strain Solution Time: 0.0159289837[s]
# Total Time: 9.75407004[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.6_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.6_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.6_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Sat 2026-03-07, 10:33:12 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-0.6_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-0.6_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.00980401039[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -0.600000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.344229937[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# ...
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.094339638188437e-09
#   Newton achieved/desired residual: 1.09433964e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -0.0227747077
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.408338726 -0.0227747075
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         126        2520
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.622104347 0.177781895
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 1.172597640e-305
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Sat 2026-03-07, 10:35:41 (+0100)
# Total Poisson Solver Time: 4.39172006[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.31172228[s]
# Total Strain Solution Time: 0.00842690468[s]
# Total Time: 8.63408995[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-50.0_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-50.0_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-50.0_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Sat 2026-03-07, 10:35:41 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Quantum_Dot_2D__V_PG_-50.0_.in)...
#    Text block TEXT in line 1.
#    Text block ENDTEXT in line 10.
#    Conditional line 189 executed.
#    Conditional line 190 executed.
#    Conditional line 191 ignored.
#    Conditional line 192 executed.
#    Conditional block IF false in line 461.
#    Conditional block ELSE true in line 468.
#    Conditional block ENDIF in line 476.
#
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Importing possible database changes from input file and checking for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG/Single_Quantum_Dot_2D__V_PG_-50.0_/
#       Defined 1D section 'x_QD' in x-direction at   y = 4013
#       Defined 1D section 'z_QD' in y-direction at   x = 0
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = -170     	spacing = 10
#     pos = -150     	spacing = 5
#     pos = -140     	spacing = 5
#     pos = -135     	spacing = 5
#     pos = -130     	spacing = 5
#     pos = -110     	spacing = 5
#     pos = -70     	spacing = 5
#     pos = -50     	spacing = 5
#     pos = -20     	spacing = 5
#     pos = 0     	spacing = 5
#     pos = 20     	spacing = 5
#     pos = 50     	spacing = 5
#     pos = 70     	spacing = 5
#     pos = 110     	spacing = 5
#     pos = 130     	spacing = 5
#     pos = 135     	spacing = 5
#     pos = 140     	spacing = 5
#     pos = 150     	spacing = 5
#     pos = 170     	spacing = 10
#
# Creating grid 2 using:
#     pos = -100     	spacing = 100
#     pos = 0     	spacing = 100
#     pos = 2949     	spacing = 50
#     pos = 3866     	spacing = 5
#     pos = 3949     	spacing = 0.5
#     pos = 3950     	spacing = 0.5
#     pos = 3995     	spacing = 1
#     pos = 4000     	spacing = 0.5
#     pos = 4015     	spacing = 0.5
#     pos = 4020     	spacing = 1
#     pos = 4065     	spacing = 0.5
#     pos = 4066     	spacing = 0.5
#     pos = 4115     	spacing = 0.1
#     pos = 4116     	spacing = 0.1
#     pos = 4123     	spacing = 2
#     pos = 4153     	spacing = 2
#     pos = 4158     	spacing = 2
#     pos = 4188     	spacing = 2
#
# Grid dimension: 67 * 554 * 1
# Number of unique grid points: 37118
# Range in 1-direction:   -170 , ... , 170
# Range in 2-direction:   -100 , ... , 4188
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#  0.0000000, -1.0000000,  0.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#   1-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.0102450848[s]
#
# Setting reference vacuum level to 6.43 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (c-Ge_QW) ******
#       dimensions: (-135,135) (3995,4020) (0,0)
# Grid dimension: 55 * 45 * 1
# Number of unique grid points: 2475
# Range in 1-direction:   -135 , ... , 135
# Range in 2-direction:   3995 , ... , 4020
#
#    spin quantization axis: (0,0,1)
# Calculating quantum density of states ... (HH)
# Calculating quantum density of states ... (LH)
#
# ********* STRUCTURE OUTPUT *****************************************************
#
# Writing (final) region indices...
# Writing last material region indices...
# Writing contact indices...
# Writing material indices...
# Writing acceptor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Calculating pseudomorphic strain...
#
# Calculating piezoelectric charges...
#
# Writing strain tensor (simulation system)...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# BG  -2.000000 V   PG  -50.000000 V   Source  0.000000 V   Drain  0.000000 V   Body  0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.298356056[s]
#
# Initialize contacts as charge neutral...
#
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	939314.8001387896
#   Newton step: 2	181657.7212430055
#   Newton step: 3	37531.30722386817
#   Newton step: 4	7223.153006267654
#   Newton step: 5	1390.783920424102
#   Newton step: 6	268.5137404442868
#   Newton step: 7	53.14263732097749
#   Newton step: 8	12.32855164386546
#   Newton step: 9	5.207964361861081
#   Newton step: 10	2.773356885656128
#   Newton step: 11	1.828058328005574
#   Newton step: 12	1.377292257463094
#   Newton step: 13	0.9658444518631265
#   Newton step: 14	0.6078093960466241
#   Newton step: 15	0.3557371896985564
#   Newton step: 16	0.2443913809817329
#   Newton step: 17	0.1467008606671726
#   Newton step: 18	1.976083990568948e-05
#   Newton achieved/desired residual: 1.30201555e-09 1.80951282e-05
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0772476126
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -2.1964395 0.0772476122
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            3         204        4080
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - POLY: -14.7133799 0.283582032
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            4         513       10260
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# ******  SOLVING QUANTUM-POISSON EQUATIONS *----------------------------
# *----  Terminates after:   max_iter = 30
#                         wanted residual =       1.000000000e+03[1/cm]
#
# QUANTUM-POISSON:  iteration = 1 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.302015553813107e-09
#   Newton achieved/desired residual: 1.30201555e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0772476126
#   conduction band minimum: 0.412343909
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1          50
#
#  Solving 1 approximate (subspace) 1-band real Schroedinger equation(s):
#    Solving dense hermitian eigenvalue problem (standard solver)...
#       Full real symmetric eigenvalue solver:           1         100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 8.007777495e-40
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# QUANTUM-POISSON:  iteration = 2 of 30 ----------------------------
#
# Solving nonlinear Poisson equation using predicted quantum densities...
#   Newton step: 1	1.302015553813107e-09
#   Newton achieved/desired residual: 1.30201555e-09 1.80951282e-05
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: 0.0772476126
#   conduction band minimum: 0.412343909
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -2.1964395 -0.322698891 0.0772476122
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            2         163        3260
#    arpack_rs_vec - converged eigenvalues:           51  of           50
#    arpack_rs_vec - used upper eigenvalues:           50
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#
#    arpack_poly - TCH: -14.7133799 -0.549853623 0.283582032
#    arpack_rs_poly: iterations(ARPACK,poly,matmul) =            1         251        5020
#    arpack_rs_vec - converged eigenvalues:          101  of          100
#    arpack_rs_vec - used upper eigenvalues:          100
#
#
# Computing quantum densities...
#
# QUANTUM-POISSON:   Residual_EDensity = 0.000000000e+00   Residual_HDensity = 2.744080486e-25
# QUANTUM-POISSON:   Residual_potential = 0.000000000e+00
#
# *----  SOLVING QUANTUM-POISSON FINISHED ----------------------------
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing electric field...
# Writing electric field (norm)...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'Delta'.
#    Writing band 'L'.
#    Writing band 'HH'.
#    Writing band 'LH'.
#    Writing band 'SO'.
#
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Sat 2026-03-07, 10:35:50 (+0100)
# Total Poisson Solver Time: 4.32117605[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 1.2944808[s]
# Total Strain Solution Time: 0.00982689857[s]
# Total Time: 8.51764607[s]
#
# ================================================================================
# DONE.
# ================================================================================
# Sweep done. Points: 20
# Sweep
# fullpath: /Users/robertjovanov/code/qpu-design-automation-toolkit/configs/nextnano_inputs/baseline_single_qd/2d/Single_Empty_Quantum_Dot_2D.in
# Input variables: 0 elements

# %% [markdown]
# #### 2.2 Lateral Dot Potential vs V_PG

# %%
from pathlib import Path
from IPython.display import Image, display

SWEEP_2_ROOT = Path("/Users/robertjovanov/code/qpu-design-automation-toolkit/runs/Single_Quantum_Dot_2D_sweep__V_PG")

gif_path = make_xqd_potential_gif(
    sweep_root=SWEEP_2_ROOT,
    out_gif=SWEEP_2_ROOT / "2DHG_xQD_potential_vs_VPG.gif",
    duration_s=500,
    xlim=(-200, 200),
    subtract_reference=None  # use None if you want absolute potential instead
)

display(Image(filename=str(gif_path)))

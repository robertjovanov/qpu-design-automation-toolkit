# %% [markdown]
# # Example 4. Use Sweep to automate the execution
# ## About this example: Sweep class
#
# Sweep allows you to automatically create input files with different values of specific variables.
#
# To work with a sweep, instantiate a Sweep class object as
#
# ```python
# my_sweep = nextnanopy.Sweep(sweep_variables, path_to_inputfile)
# ```
#
# Here sweep_variables should be a dict, where keys are the names of variables and the values are iterable objects of values. (ideally lists)
#
# ```python
# sweep_variables = {'varname1':[val0,val1,val2...],'varname2':[val10,val11,val12...]...}
# ```
#
# The name of variables to sweep should coincide with the names of variables in input file (see Example1).

# %%
import nextnanopy as nn

# this output is not consistent, should display variables of the sweep, but it works further on which is weird
path = r'sweep_example.in'
sweep_variables = {'ALLOY':[0.3,0.6], 'SIZE':[80,100]}
my_sweep = nn.Sweep(sweep_variables, path)
print(my_sweep)
# Out:
# Sweep
# fullpath: sweep_example.in
# Input variables: 0 elements

# %% [markdown]
# To save a sweep, use

# %%
# If files exist it doesn't create new ones, so no duplicated simulations
my_sweep.save_sweep()

# %% [markdown]
# After saving, input files are created in the directory of the initial input file. One can access info about the input files via

# %%
my_sweep.input_files
# Out:
# [InputFile
#  fullpath: sweep_example__ALLOY_0.3_SIZE_80_.in
#  Input variables: 8 elements
#  	$BIAS = 0.0 # Gate voltage(V)
#  	$ALLOY = 0.3 # THIS VARIABLE IS UNDER SWEEP
#  	$SIZE = 80 # THIS VARIABLE IS UNDER SWEEP
#  	$DOPECONC = 3e+18 # donor concentration of 10nm doping layer (cm^-3)
#  	$DOPEPOS = 65 # distance between AlGaAs-GaAs interface and delta doping position (nm)
#  	$MINGRID = 0.1 # minimum grid spacing (nm)
#  	$NUMEV = 10 # number of eigenvalues to be calculated
#  	$BARRIER = 0.7 # height of left Schottky barrier (eV),
#  InputFile
#  fullpath: sweep_example__ALLOY_0.3_SIZE_100_.in
#  Input variables: 8 elements
#  	$BIAS = 0.0 # Gate voltage(V)
#  	$ALLOY = 0.3 # THIS VARIABLE IS UNDER SWEEP
#  	$SIZE = 100 # THIS VARIABLE IS UNDER SWEEP
#  	$DOPECONC = 3e+18 # donor concentration of 10nm doping layer (cm^-3)
#  	$DOPEPOS = 65 # distance between AlGaAs-GaAs interface and delta doping position (nm)
#  	$MINGRID = 0.1 # minimum grid spacing (nm)
#  	$NUMEV = 10 # number of eigenvalues to be calculated
#  	$BARRIER = 0.7 # height of left Schottky barrier (eV),
#  InputFile
#  fullpath: sweep_example__ALLOY_0.6_SIZE_80_.in
#  Input variables: 8 elements
#  	$BIAS = 0.0 # Gate voltage(V)
#  	$ALLOY = 0.6 # THIS VARIABLE IS UNDER SWEEP
#  	$SIZE = 80 # THIS VARIABLE IS UNDER SWEEP
#  	$DOPECONC = 3e+18 # donor concentration of 10nm doping layer (cm^-3)
#  	$DOPEPOS = 65 # distance between AlGaAs-GaAs interface and delta doping position (nm)
#  	$MINGRID = 0.1 # minimum grid spacing (nm)
#  	$NUMEV = 10 # number of eigenvalues to be calculated
#  	$BARRIER = 0.7 # height of left Schottky barrier (eV),
#  InputFile
#  fullpath: sweep_example__ALLOY_0.6_SIZE_100_.in
#  Input variables: 8 elements
#  	$BIAS = 0.0 # Gate voltage(V)
#  	$ALLOY = 0.6 # THIS VARIABLE IS UNDER SWEEP
#  	$SIZE = 100 # THIS VARIABLE IS UNDER SWEEP
#  	$DOPECONC = 3e+18 # donor concentration of 10nm doping layer (cm^-3)
#  	$DOPEPOS = 65 # distance between AlGaAs-GaAs interface and delta doping position (nm)
#  	$MINGRID = 0.1 # minimum grid spacing (nm)
#  	$NUMEV = 10 # number of eigenvalues to be calculated
#  	$BARRIER = 0.7 # height of left Schottky barrier (eV)]

# %% [markdown]
# To execute the sweep, run
# ```python
# Sweep.execute_sweep()
# ```
#
# Under execution, a few things will happen.
# 1. The directory inputfilename_sweep_var1_var2_...varn will be created in the output directory.
# 2. The sweep.info file with the information of the sweep is saved there.
# 3. Input files from sweep.input_files are executed and output is saved to the mentioned folder.
#
# Sweep.execute() has 5 optional parameters + can take any parameter accepted by nextnanopy.InputFile.execute().
#
# 1. delete_input_files: bool, optional
#
# When set to `True`, input_files will be deleted after execution. Default is `False`.
#
# 2. overwrite: bool, optional
#
# When set to `True`, the output will overwrite the old output. When `False`, execution will create new output folder (with the unique name, created by adding an integer to the foldername). Default is `False`.
#
# 3. show_log: bool, optional
#
# When set to `True`, the simulation log is displayed in the console, while `False` suppresses the log. Default is `True`. Note that the log file is always saved in the output folders regardless of this option.
#
# 4. convergenceCheck: bool, optional
#
# When set to `True`, nextnanopy scans the log file of the simulation performed and check whether the solution has converged. If it did not converge, nextnanopy warns you and ask if you want to proceed with postprocessing. Note that non-converged solutions are not reliable and further calculation and/or visualization from them do not make much sense. Default is `False`.
#
# 5.  parallel_limit: int, optional
#
# number of simulation to run simultaniously. Espicially usefull for simple simulations which migh be more efficiently rn in parallel. Be aware that some nextnano solvers parallelize computations internally in threads (controlled by --threads in nextnanopy config). To avoid unexpected behaviour and not desirable decrease of simulation speed use the rule: parallel_limit*threads<= number of physical cores of the mahcine
# default parallel_limit =  1
#
# **kwags
# Any other parameter accepted by nextnanopy.InputFile.execute() e.g. exe, license, database, outputdirectory

# %% [markdown]
# Example of the simulation in parallel (2 Input files at a time)

# %%
my_sweep.execute_sweep(delete_input_files = False, overwrite = True, show_log = True, convergenceCheck = True, parallel_limit = 2)
# Out:
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
#
# ================================================================================
# PREPARING...
# ================================================================================
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.3_SIZE_80_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_80_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_80_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Tue 2026-01-20, 17:14:59 (+0100)
#
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.3_SIZE_100_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_100_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_100_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Tue 2026-01-20, 17:14:59 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_80_.in)...
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.3_SIZE_100_.in)...
#
#
#
# WARNING: Using database specified in command line.
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Checking database for errors...
#
#
# Material database initialized.
#
# Checking license:
#
# Material database initialized.
#
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.3_SIZE_80_/
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.3_SIZE_100_/
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = 0     	spacing = 0.5
#     pos = 10     	spacing = 0.5
#     pos = 20     	spacing = 0.5
#     pos = 30     	spacing = 0.5
#     pos = 90     	spacing = 0.1
#     pos = 400     	spacing = 5
#
# Grid dimension: 548 * 1 * 1
# Number of unique grid points: 548
# Range in 1-direction:   0 , ... , 400
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  1.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#
#     pos = 0     	spacing = 0.5
#     pos = 10     	spacing = 0.5
#     pos = 40     	spacing = 0.5
#     pos = 50     	spacing = 0.5
#     pos = 110     	spacing = 0.1
#     pos = 400     	spacing = 5
#
# Grid dimension: 572 * 1 * 1
# Number of unique grid points: 572
# Range in 1-direction:   0 , ... , 400
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  1.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#
#
# Start initializing structure.
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.000214099884[s]
#
# Setting reference vacuum level to 6.3 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (2DEG) ******
#       dimensions: (105,250) (0,0) (0,0)
# Grid dimension: 232 * 1 * 1
# Number of unique grid points: 232
# Range in 1-direction:   105.031954 , ... , 248.470823
#
#    spin quantization axis: (1,0,0)
# Calculating quantum density of states ... (Gamma)
# Finished initializing structure.
# Structure initialization time: 0.000218153[s]
#
# Setting reference vacuum level to 6.3 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (2DEG) ******
#       dimensions: (85,250) (0,0) (0,0)
# Grid dimension: 249 * 1 * 1
# Number of unique grid points: 249
# Range in 1-direction:   85.0319539 , ... , 248.032375
#
#    spin quantization axis: (1,0,0)
# Calculating quantum density of states ... (Gamma)
#
# ********* STRUCTURE OUTPUT *****************************************************
# Writing contact indices...
#
# ********* STRUCTURE OUTPUT *****************************************************
# Writing contact indices...
# Writing material indices...
# Writing material indices...
# Writing donor density...
# Writing donor density...
# Writing fixed charge density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
# Determine dirichlet points for contacts...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# gate  0.000000 V   backgate  -0.000000 V
#
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# gate  0.000000 V   backgate  -0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.000749111176[s]
#
# No charge neutrality initialization for contacts needed (no ohmic or charge neutral contact points found).
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
# Fermi level initial solution time: 0.000561952591[s]
#
# No charge neutrality initialization for contacts needed (no ohmic or charge neutral contact points found).
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#    Number of bisection failures in Poisson: 545
#    Bisection - achieved/desired residual:  2.916959666e+21 ,  1.000000000e+03  [carriers/cm^3]
#              - achieved/desired accuracy:  5.000000000e+00 ,  8.617333262e-05  [V]
#
# WARNING: Charge neutral potential initialization may not have converged.
#          Please check bisection residual/accuracy, or enable the robust bisection algorithm.
#
# Charge Neutrality time: 0.00136208534[s]
#
# Solving nonlinear Poisson equation using classical densities...
#    Number of bisection failures in Poisson: 569
#    Bisection - achieved/desired residual:  2.916959666e+21 ,  1.000000000e+03  [carriers/cm^3]
#              - achieved/desired accuracy:  5.000000000e+00 ,  8.617333262e-05  [V]
#
# WARNING: Charge neutral potential initialization may not have converged.
#          Please check bisection residual/accuracy, or enable the robust bisection algorithm.
#
# Charge Neutrality time: 0.00141620636[s]
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	121.8847383317415
#   Newton step: 1	123.4283996944577
#   Newton step: 2	16.97314992427739
#   Newton step: 2	16.55478440640494
#   Newton step: 3	3.263599327723646
#   Newton step: 3	3.182965717566375
#   Newton step: 4	0.6564435659283163
#   Newton step: 4	0.6434438813993895
#   Newton step: 5	0.1488943055741863
#   Newton step: 5	0.1702675637459774
#   Newton step: 6	0.03766206084172861
#   Newton step: 6	0.06143054600720926
#   Newton step: 7	0.01111605423968859
#   Newton step: 7	0.02173672947051555
#   Newton step: 8	0.005649258588222751
#   Newton step: 8	0.005038157970851849
#   Newton step: 9	0.002999100291682779
#   Newton step: 9	0.0008735164609252334
#   Newton step: 10	0.001076878761837786
#   Newton step: 11	2.714990366140976e-05
#   Newton step: 10	8.36233623013919e-05
#   Newton step: 12	6.87366999351219e-06
#   Newton step: 11	2.530500490712514e-05
#   Newton step: 12	5.91106637284978e-06
#   Newton step: 13	7.712135376001672e-07
#   Newton step: 14	1.174581954671204e-08
#   Newton step: 13	5.294542377847006e-07
#   Newton achieved/desired residual: 2.90854787e-12 1.80951282e-10
#
# Computing classical densities...
#   Newton step: 14	4.939792661741849e-09
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -1.51800187
#   conduction band minimum: -0.0278041269
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#   Newton achieved/desired residual: 9.13495085e-13 1.80951282e-10
#
# Computing classical densities...
#     Tridiagonal real symmetric eigenvalue solver:           1          10
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -1.51812355
#   conduction band minimum: -0.032146641
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#     Tridiagonal real symmetric eigenvalue solver:           1          10
#
#
# Computing quantum densities...
#
#
# Computing quantum densities...
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
# Writing global characteristics data...
#
# Writing electrostatic potential...
#
# Writing electrostatic potential...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'HH'.
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'HH'.
#
# Writing electron Fermi level...
#
# Writing electron Fermi level...
# Writing hole Fermi level...
# Writing hole Fermi level...
# Writing all Fermi levels into one file...
# Writing all Fermi levels into one file...
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
#
# Writing carrier densities...
# Writing ionized dopant densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Tue 2026-01-20, 17:15:01 (+0100)
#
# End time: Tue 2026-01-20, 17:15:01 (+0100)
# Total Poisson Solver Time: 0.00958323479[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.00175905228[s]
# Total Time: 1.38670301[s]
#
# ================================================================================
# DONE.
# ================================================================================
# Total Poisson Solver Time: 0.00880002975[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.00259613991[s]
# Total calculation time for matrix elements and lifetimes: 9.53674316e-07[s]
# Total Time: 1.39380598[s]
#
# ================================================================================
# DONE.
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
# WARNING: Option --threads is specified, but parallel execution is not enabled in this executable.
#
# ================================================================================
# PREPARING...
# ================================================================================
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.6_SIZE_80_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_80_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_80_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Tue 2026-01-20, 17:15:01 (+0100)
#
#
# Checking input files...
#
#
# Reading environment and checking paths...
#
# ================================================================================
# RUNNING..
# ================================================================================
# Starting execution as:
# /Applications/nextnano/2025_12_17/nextnano++/bin/nextnano++_gcc_macOS --old --license /Applications/nextnano/2025_12_17/licenses/license.txt --database /Applications/nextnano/2025_12_17/nextnano++/database/database.nnp --threads 0 --outputdirectory /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.6_SIZE_100_ --noautooutdir /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_100_.in
#
# nextnano++ 2.4.27 from 2025-12-16 (library 2025-07-29)
# =============================================================================
# COPYRIGHT NOTICE
# =============================================================================
# ANY USE OF THE NEXTNANO++ CODE CONSTITUTES ACCEPTANCE OF THE TERMS OF THE
# COPYRIGHT NOTICE.
#
# The terms of copyright of the nextnano++ code and of third party source codes
# and libraries used in the nextnano++ code can be found in the file
# 'documentation/copyright/copyright_notice_nextnano++.pdf' in your
# installation folder.
#
# In case this file is missing or seems incomplete or corrupted, please contact
# our support team at https://nextnano.com/goto/support to receive a new copy.
# =============================================================================
#
#
# =============================================================================
#  PROCESSING INPUT FILE: /Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_100_.in
#
#  nextnano++  v2.4.27
# =============================================================================
#
# Start time: Tue 2026-01-20, 17:15:01 (+0100)
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_80_.in)...
#
#
# WARNING: Using database specified in command line.
#
# Reading input file (/Users/robertjovanov/code/qpu-design-automation-toolkit/notebooks/tutorials_nextnanopy/sweep_example__ALLOY_0.6_SIZE_100_.in)...
#
#
# WARNING: Using database specified in command line.
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
# Reading database file (/Applications/nextnano/2025_12_17/nextnano++/database/database.nnp)...
#
# Checking database for errors...
#
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.6_SIZE_80_/
#
# Material database initialized.
#
# Checking license:
# License file is specified as: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#    Checking: /Applications/nextnano/2025_12_17/licenses/license.txt
#        File was found and will be used as license file.
#
#  Reading in license file: /Applications/nextnano/2025_12_17/licenses/license.txt
#
#  ----------------------------------------------------------
#  License issued to:
#  First name(s):  Robert
#  Last name(s):   Jovanov
#  Organization:
#  Country:
#  email:          robert.jovanov2@student.uva.nl
#
#  License valid until expiry date:
#  Date: 2026-12-03
#  License issued:
#  Date: 2026-01-08
#
#  License is valid.
#  ----------------------------------------------------------
#
#
# ********* SETUP SIMULATION *****************************************************
#
# NOTE: Using output directory specified from command line (nextnanomat),
#
# NOTE: Setting output directory to: /Users/robertjovanov/code/qpu-design-automation-toolkit/runs/sweep_example_sweep__ALLOY__SIZE/sweep_example__ALLOY_0.6_SIZE_100_/
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = 0     	spacing = 0.5
#     pos = 10     	spacing = 0.5
#     pos = 20     	spacing = 0.5
#     pos = 30     	spacing = 0.5
#     pos = 90     	spacing = 0.1
#     pos = 400     	spacing = 5
#
# Grid dimension: 548 * 1 * 1
# Number of unique grid points: 548
# Range in 1-direction:   0 , ... , 400
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  1.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#
#
# Start initializing structure.
# Finished initializing structure.
# Structure initialization time: 0.000218868256[s]
#
# Setting reference vacuum level to 6.3 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (2DEG) ******
#       dimensions: (85,250) (0,0) (0,0)
# Grid dimension: 249 * 1 * 1
# Number of unique grid points: 249
# Range in 1-direction:   85.0319539 , ... , 248.032375
#
#    spin quantization axis: (1,0,0)
# Calculating quantum density of states ... (Gamma)
#
# ********* STRUCTURE OUTPUT *****************************************************
# Writing contact indices...
# Writing material indices...
# Writing donor density...
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
# Determine dirichlet points for contacts...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# gate  0.000000 V   backgate  -0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.000108003616[s]
#
# No charge neutrality initialization for contacts needed (no ohmic or charge neutral contact points found).
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
#    Number of bisection failures in Poisson: 545
#    Bisection - achieved/desired residual:  2.916959666e+21 ,  1.000000000e+03  [carriers/cm^3]
#              - achieved/desired accuracy:  5.000000000e+00 ,  8.617333262e-05  [V]
#
# WARNING: Charge neutral potential initialization may not have converged.
#          Please check bisection residual/accuracy, or enable the robust bisection algorithm.
#
# Charge Neutrality time: 0.00130701065[s]
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	117.4848483179858
#   Newton step: 2	16.86987422782248
#   Newton step: 3	3.252540780997434
#   Newton step: 4	0.6645801817277773
#   Newton step: 5	0.1674027314403901
#   Newton step: 6	0.05112307710331951
#
# ********* Simulation Grid *********
#
# Creating grid 1 using:
#     pos = 0     	spacing = 0.5
#     pos = 10     	spacing = 0.5
#     pos = 40     	spacing = 0.5
#     pos = 50     	spacing = 0.5
#     pos = 110     	spacing = 0.1
#     pos = 400     	spacing = 5
#
# Grid dimension: 572 * 1 * 1
# Number of unique grid points: 572
# Range in 1-direction:   0 , ... , 400
#
#
# ********* Rotation Matrix *********
#  1.0000000,  0.0000000,  0.0000000
#  0.0000000,  1.0000000,  0.0000000
#  0.0000000,  0.0000000,  1.0000000
#
# ********* Periodicity *************
#   0-direction:  not periodic
#
#   Newton step: 7	0.02054458847577265
#   Newton step: 8	0.01164953827498175
#   Newton step: 9	0.0002819998887470167
#   Newton step: 10	8.540115910433765e-05
#   Newton step: 11	2.711522235206028e-05
#   Newton step: 12	6.853104367057209e-06
#   Newton step: 13	7.652305606772422e-07
#   Newton step: 14	1.153304285679014e-08
#   Newton achieved/desired residual: 2.80965738e-12 1.80951282e-10
#
# Computing classical densities...
#
# Start initializing structure.
#
# Solving Quantum Mechanics ---- (and calculate density)
#
# Finished initializing structure.
# Structure initialization time: 0.000236034393[s]
#
# Setting reference vacuum level to 6.3 eV.
#
# NOTE: Electron minimum density is 1 cm^-3.
# NOTE: Hole minimum density is 1 cm^-3.
#
# NOTE: Electron maximum density is 1e+30 cm^-3.
# NOTE: Hole maximum density is 1e+30 cm^-3.
#
# ***** Quantum Subgrid (2DEG) ******
#       dimensions: (105,250) (0,0) (0,0)
# Grid dimension: 232 * 1 * 1
# Number of unique grid points: 232
# Range in 1-direction:   105.031954 , ... , 248.470823
#
#    spin quantization axis: (1,0,0)
# Calculating quantum density of states ... (Gamma)
#
# ********* STRUCTURE OUTPUT *****************************************************
# Writing contact indices...
#   valence band maximum: -1.51800452
#   conduction band minimum: -0.0295473527
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#     Tridiagonal real symmetric eigenvalue solver:           1          10
#
#
# Computing quantum densities...
# Writing material indices...
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing electrostatic potential...
# Writing donor density...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'HH'.
# Writing fixed charge density...
#
# ********* START CALCULATION ****************************************************
#
#
# Writing electron Fermi level...
# Determine dirichlet points for contacts...
#
# Discretizing Poisson equation...
#
#
#
#
# ========= STARTING CALCULATION FOR BIAS POINT ==================================
# gate  0.000000 V   backgate  -0.000000 V
#
# Determine electron Fermi level dirichlet values in contacts...
# Determine hole Fermi level dirichlet values in contacts...
# Initialize Fermi levels...
# Fermi level initial solution time: 0.000106096268[s]
#
# No charge neutrality initialization for contacts needed (no ohmic or charge neutral contact points found).
# Determine potential Dirichlet values in Schottky and ohmic contacts...
# Update contact discretization in Poisson equation...
#
# Initialize electrostatic potential...
# Writing hole Fermi level...
#    Number of bisection failures in Poisson: 569
#    Bisection - achieved/desired residual:  2.916959666e+21 ,  1.000000000e+03  [carriers/cm^3]
#              - achieved/desired accuracy:  5.000000000e+00 ,  8.617333262e-05  [V]
#
# WARNING: Charge neutral potential initialization may not have converged.
#          Please check bisection residual/accuracy, or enable the robust bisection algorithm.
#
# Charge Neutrality time: 0.00132393837[s]
#
# Solving nonlinear Poisson equation using classical densities...
#   Newton step: 1	115.6940994645114
# Writing all Fermi levels into one file...
#   Newton step: 2	16.40504327233314
#   Newton step: 3	3.163158811088425
#   Newton step: 4	0.6520329007259568
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#   Newton step: 5	0.191717491985798
#   Newton step: 6	0.07556743291874303
#   Newton step: 7	0.03177602504730334
#   Newton step: 8	0.01036567078611318
#   Newton step: 9	0.002243381805589971
#   Newton step: 10	0.0001164881144412042
#   Newton step: 11	2.507452866843282e-05
#   Newton step: 12	5.780117833621768e-06
#   Newton step: 13	4.999199865350961e-07
#   Newton step: 14	4.327231651276335e-09
#   Newton achieved/desired residual: 8.24125049e-13 1.80951282e-10
#
# Computing classical densities...
#
# Solving Quantum Mechanics ---- (and calculate density)
#
#   valence band maximum: -1.51814269
#   conduction band minimum: -0.0471080698
#
#  Solving 1 exact 1-band real Schroedinger equation(s):
#     Tridiagonal real symmetric eigenvalue solver:           1          10
#
#
# Computing quantum densities...
#
# Solving Quantum Mechanics ---- (quantum regions without density only)
#
#
# Solving Quantum Mechanics ---- determine k-dispersions
#
#
# ********* OUTPUT ***************************************************************
#
# Writing characteristics data for bias point...
# Writing global characteristics data...
#
# Writing carrier densities...
#
# Writing electrostatic potential...
#
# Writing band edges...
#    Writing band 'Gamma'.
#    Writing band 'HH'.
# Writing ionized dopant densities...
#
# Writing electron Fermi level...
# Writing hole Fermi level...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Tue 2026-01-20, 17:15:03 (+0100)
# Writing all Fermi levels into one file...
#
# Writing results from quantum calculations...
#      Writing spectra and states...
#
# Writing carrier densities...
# Writing ionized dopant densities...
#
# ********* FINISHED CALCULATION *************************************************
#
# End time: Tue 2026-01-20, 17:15:03 (+0100)
# Total Poisson Solver Time: 0.00852203369[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.00145316124[s]
# Total Time: 1.33688307[s]
#
# ================================================================================
# DONE.
# ================================================================================
# Total Poisson Solver Time: 0.00922989845[s]
# Total Current Solver Time: 0[s]
# Total Quantum Solver Time: 0.00162005424[s]
# Total Time: 1.34135008[s]
#
# ================================================================================
# DONE.
# ================================================================================
#
# Waiting queue is empty, all execution and logging are finished

# %% [markdown]
# Example of the simulation in sequence (if you want to run the sweep which was already executed, save it one more time)

# %%
my_sweep.save_sweep(delete_old_files = False)
my_sweep.execute_sweep(delete_input_files = False, overwrite = True, show_log = False, convergenceCheck = True, parallel_limit = 1)
# Out:
# Executing simulations [1/4]...
#
# Executing simulations [2/4]...
#
# Executing simulations [3/4]...
#
# Executing simulations [4/4]...

# %% [markdown]
# Please contact python@nextnano.com for any issues with this document.
